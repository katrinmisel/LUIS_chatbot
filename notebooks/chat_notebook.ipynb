# %% [markdown]
# ## Travel chatbot
#
# 1. Create a bot with the Microsoft Bot Framework.
# 2. Deploy it to the Web App Service (no Azure bot).
# 3. Connect the bot to the Azure Cognitive Service LUIS for natural language processing.
# 4. Train the LUIS model using the data.
# 5. Use the aiohttp library to create a HTTP server for the bot to run on.
# 6. Test the bot using the Bot Framework Emulator.

# %%
import pandas as pd
import json
from sklearn.model_selection import train_test_split

# %%
df = pd.read_json("frames/frames.json")
df.head()
# Out:
#      user_id                                              turns  wizard_id  \
# 0  U22HTHYNP  [{'text': 'I'd like to book a trip to Atlantis...  U21DKG18C
# 1  U21E41CQP  [{'text': 'Hello, I am looking to book a vacat...  U21DMV0KA
# 2  U21RP4FCY  [{'text': 'Hello there i am looking to go on a...  U21E0179B
# 3  U22HTHYNP  [{'text': 'Hi I'd like to go to Caprica from B...  U21DKG18C
# 4  U21E41CQP  [{'text': 'Hello, I am looking to book a trip ...  U21DMV0KA
#
#                                      id  \
# 0  e2c0fc6c-2134-4891-8353-ef16d8412c9a
# 1  4a3bfa39-2c22-42c8-8694-32b4e34415e9
# 2  6e67ed28-e94c-4fab-96b6-68569a92682f
# 3  5ae76e50-5b48-4166-9f6d-67aaabd7bcaa
# 4  24603086-bb53-431e-a0d8-1dcc63518ba9
#
#                                               labels
# 0  {'userSurveyRating': 4.0, 'wizardSurveyTaskSuc...
# 1  {'userSurveyRating': 3.0, 'wizardSurveyTaskSuc...
# 2  {'userSurveyRating': 2.0, 'wizardSurveyTaskSuc...
# 3  {'userSurveyRating': 5.0, 'wizardSurveyTaskSuc...
# 4  {'userSurveyRating': 5.0, 'wizardSurveyTaskSuc...

# %%
# get the 'frames' data from json of cell: 
user = 0
print(df.iloc[user]['turns'][0]['text'])
df.iloc[user]['turns'][0]['labels']['acts']
# Out:
# I'd like to book a trip to Atlantis from Caprica on Saturday, August 13, 2016 for 8 adults. I have a tight budget of 1700.
# [{'args': [{'val': 'book', 'key': 'intent'}], 'name': 'inform'},
#  {'args': [{'val': 'Atlantis', 'key': 'dst_city'},
#    {'val': 'Caprica', 'key': 'or_city'},
#    {'val': 'Saturday, August 13, 2016', 'key': 'str_date'},
#    {'val': '8', 'key': 'n_adults'},
#    {'val': '1700', 'key': 'budget'}],
#   'name': 'inform'}]

# %%
df.shape
# Out:
# (1369, 5)

# %% [markdown]
# ### Convert frames data to Luis compatible data

# %%
luis_entities = [
    "or_city",
    "dst_city",
    "str_date",
    "end_date",
    "budget"
]

def get_user_requests(data, index):

    json_part = {}
    txt = data.iloc[index]['turns'][0]["text"].lower()
    json_part["text"] = txt
    json_part["intentName"] = "BookFlight"

    entities = []

    for act in data.iloc[index]['turns'][0]['labels']['acts']:
        
        for arg in act['args']:
            if arg['key'] in luis_entities:
                entity = {}
                key = arg['key'].lower()
                if 'val' in arg.keys():
                    val = arg['val'].lower()
                    if val != '-1':
                        startPos = txt.index(val)
                        endPos = startPos + len(val)
                        entity['entityName'] = key
                        entity['startCharIndex'] = startPos
                        entity['endCharIndex'] = endPos
                        entities.append(entity)

    json_part['entityLabels'] = entities

    return json_part


get_user_requests(df, 1)
# Out:
# {'text': 'hello, i am looking to book a vacation from gotham city to mos eisley for $2100.',
#  'intentName': 'BookFlight',
#  'entityLabels': [{'entityName': 'dst_city',
#    'startCharIndex': 59,
#    'endCharIndex': 69},
#   {'entityName': 'or_city', 'startCharIndex': 44, 'endCharIndex': 55},
#   {'entityName': 'budget', 'startCharIndex': 75, 'endCharIndex': 79}]}

# %%
def convert_luis(data):
    luis_data = []
    for i in range(data.shape[0]):
        json_part = get_user_requests(data, i)
        luis_data.append(json_part)
    return luis_data

luis_data = convert_luis(df)

# %%
print("Length luis_data: " + str(len(luis_data)))
luis_data
# Out:
# Length luis_data: 1369
# [{'text': "i'd like to book a trip to atlantis from caprica on saturday, august 13, 2016 for 8 adults. i have a tight budget of 1700.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 27,
#     'endCharIndex': 35},
#    {'entityName': 'or_city', 'startCharIndex': 41, 'endCharIndex': 48},
#    {'entityName': 'str_date', 'startCharIndex': 52, 'endCharIndex': 77},
#    {'entityName': 'budget', 'startCharIndex': 117, 'endCharIndex': 121}]},
#  {'text': 'hello, i am looking to book a vacation from gotham city to mos eisley for $2100.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 59,
#     'endCharIndex': 69},
#    {'entityName': 'or_city', 'startCharIndex': 44, 'endCharIndex': 55},
#    {'entityName': 'budget', 'startCharIndex': 75, 'endCharIndex': 79}]},
#  {'text': 'hello there i am looking to go on a vacation with my family to gotham city, can you help me?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 63,
#     'endCharIndex': 74}]},
#  {'text': "hi i'd like to go to caprica from busan, between sunday august 21, 2016 and wednesday august 31, 2016",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 21,
#     'endCharIndex': 28},
#    {'entityName': 'or_city', 'startCharIndex': 34, 'endCharIndex': 39},
#    {'entityName': 'str_date', 'startCharIndex': 49, 'endCharIndex': 71},
#    {'entityName': 'end_date', 'startCharIndex': 76, 'endCharIndex': 101}]},
#  {'text': 'hello, i am looking to book a trip for 2 adults and 6 children for $21,300 or less. we are departing from kochi for denver.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 67,
#     'endCharIndex': 74},
#    {'entityName': 'or_city', 'startCharIndex': 106, 'endCharIndex': 111},
#    {'entityName': 'dst_city', 'startCharIndex': 116, 'endCharIndex': 122}]},
#  {'text': 'hey, i want to go to st. louis on the 17th of august',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 21,
#     'endCharIndex': 30},
#    {'entityName': 'str_date', 'startCharIndex': 38, 'endCharIndex': 52}]},
#  {'text': "i'm looking for a trip to gotham city leaving from kakariko village on saturday, august 13, 2016. 3 adults for no more than $2400 usd.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 26,
#     'endCharIndex': 37},
#    {'entityName': 'or_city', 'startCharIndex': 51, 'endCharIndex': 67},
#    {'entityName': 'str_date', 'startCharIndex': 71, 'endCharIndex': 96},
#    {'entityName': 'budget', 'startCharIndex': 124, 'endCharIndex': 133}]},
#  {'text': 'hello, i would like to book a 2-week trip leaving from melbourne on august 27. i would like to go to mannheim.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 55,
#     'endCharIndex': 64},
#    {'entityName': 'dst_city', 'startCharIndex': 101, 'endCharIndex': 109},
#    {'entityName': 'str_date', 'startCharIndex': 68, 'endCharIndex': 77}]},
#  {'text': 'hello, i am planning to book a trip to pittsborgh',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 39,
#     'endCharIndex': 49}]},
#  {'text': 'hi, i need to go to mos eisley for a wedding, leaving on saturday, august 13, 2016 and returning on tuesday, august 16, 2016. preferably for $3700.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 20,
#     'endCharIndex': 30},
#    {'entityName': 'str_date', 'startCharIndex': 57, 'endCharIndex': 82},
#    {'entityName': 'end_date', 'startCharIndex': 100, 'endCharIndex': 124},
#    {'entityName': 'budget', 'startCharIndex': 141, 'endCharIndex': 146}]},
#  {'text': "i'd like to get away from monday, august 15, 2016 to wednesday, august 31, 2016. my budget is $3200 and i would leave from detroit.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 26,
#     'endCharIndex': 49},
#    {'entityName': 'end_date', 'startCharIndex': 53, 'endCharIndex': 79},
#    {'entityName': 'budget', 'startCharIndex': 94, 'endCharIndex': 99},
#    {'entityName': 'or_city', 'startCharIndex': 123, 'endCharIndex': 130}]},
#  {'text': 'good day, please book me a trip from vancouver, jamaica to recife. i would like to leave for 17 days on august 24.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 37,
#     'endCharIndex': 55},
#    {'entityName': 'dst_city', 'startCharIndex': 59, 'endCharIndex': 65},
#    {'entityName': 'str_date', 'startCharIndex': 104, 'endCharIndex': 113}]},
#  {'text': 'hi im looking for a nice destination that i could go to from columbus',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 61,
#     'endCharIndex': 69}]},
#  {'text': "hi, i have a big family and we can't afford a big vacation, we want to go to atlantis from mos eisley for $3600 at most.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 77,
#     'endCharIndex': 85},
#    {'entityName': 'or_city', 'startCharIndex': 91, 'endCharIndex': 101},
#    {'entityName': 'budget', 'startCharIndex': 106, 'endCharIndex': 111}]},
#  {'text': "hi, i'm leaving from diagon alley and going to coruscant on a budget of $3400. the dates don't matter, but i cannot afford anything over my budget.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 21,
#     'endCharIndex': 33},
#    {'entityName': 'dst_city', 'startCharIndex': 47, 'endCharIndex': 56},
#    {'entityName': 'budget', 'startCharIndex': 72, 'endCharIndex': 77}]},
#  {'text': 'hi there, im from vitoria and i want to go on vacation',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 18,
#     'endCharIndex': 25}]},
#  {'text': 'hi, me and my family want to take a trip to kakariko village.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 44,
#     'endCharIndex': 60}]},
#  {'text': "hi, i'm looking for a trip  from thursday, august 18, 2016 to thursday, september 8, 2016 to mexico city",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 33,
#     'endCharIndex': 58},
#    {'entityName': 'end_date', 'startCharIndex': 62, 'endCharIndex': 89},
#    {'entityName': 'dst_city', 'startCharIndex': 93, 'endCharIndex': 104}]},
#  {'text': 'hi im from caprica looking to book a vacation to hyrule',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 18},
#    {'entityName': 'dst_city', 'startCharIndex': 49, 'endCharIndex': 55}]},
#  {'text': "hey man, imma leave from godric's hollow on august 27, 2016 and go to goiania. can't pay more than 4300usd. watcha got?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 25,
#     'endCharIndex': 40},
#    {'entityName': 'str_date', 'startCharIndex': 44, 'endCharIndex': 59},
#    {'entityName': 'dst_city', 'startCharIndex': 70, 'endCharIndex': 77},
#    {'entityName': 'budget', 'startCharIndex': 99, 'endCharIndex': 106}]},
#  {'text': 'hi im from alexandria looking to book a 12 day vacation',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 21}]},
#  {'text': 'hi im from termina can we find a vacation that starts on the 13th?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 18},
#    {'entityName': 'str_date', 'startCharIndex': 57, 'endCharIndex': 65}]},
#  {'text': "hi. i'm looking for an adventure from thursday, august 18 to saturday, september 3. i'm thinking of going to fortaleza. yes, with free breakfast of course. i'm leaving from essen.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 38,
#     'endCharIndex': 57},
#    {'entityName': 'end_date', 'startCharIndex': 61, 'endCharIndex': 82},
#    {'entityName': 'dst_city', 'startCharIndex': 109, 'endCharIndex': 118},
#    {'entityName': 'or_city', 'startCharIndex': 173, 'endCharIndex': 178}]},
#  {'text': "hi, my name is harry potter and i'd like to go to hogsmeade leaving from kakariko village on saturday, august 13th for 3 nights with 11 friends.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 50,
#     'endCharIndex': 59},
#    {'entityName': 'or_city', 'startCharIndex': 73, 'endCharIndex': 89},
#    {'entityName': 'str_date', 'startCharIndex': 93, 'endCharIndex': 114}]},
#  {'text': 'hi looking to go on vacation on the 13th of august',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 36,
#     'endCharIndex': 50}]},
#  {'text': "hi. i live in busan and i'd like to go to las vegas from wednesday august 17 to monday september 5. what's available?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 14,
#     'endCharIndex': 19},
#    {'entityName': 'dst_city', 'startCharIndex': 42, 'endCharIndex': 51},
#    {'entityName': 'str_date', 'startCharIndex': 57, 'endCharIndex': 76},
#    {'entityName': 'end_date', 'startCharIndex': 80, 'endCharIndex': 98}]},
#  {'text': 'hello, i want to leave from seoul on august 27 and return on september 9. you can go to manaus.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 28,
#     'endCharIndex': 33},
#    {'entityName': 'str_date', 'startCharIndex': 37, 'endCharIndex': 46},
#    {'entityName': 'end_date', 'startCharIndex': 61, 'endCharIndex': 72},
#    {'entityName': 'dst_city', 'startCharIndex': 88, 'endCharIndex': 94}]},
#  {'text': "i'm a polygamist and i'd like to travel with my 6 partners and 1 child to san juan from pittsburgh on a budget of 6600 usd",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 74,
#     'endCharIndex': 82},
#    {'entityName': 'or_city', 'startCharIndex': 88, 'endCharIndex': 98},
#    {'entityName': 'budget', 'startCharIndex': 114, 'endCharIndex': 122}]},
#  {'text': "hi, send me on a 10 day-trip away from cairo. i'd like to leave august 15. send me to sendai. money is not object",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 39,
#     'endCharIndex': 44},
#    {'entityName': 'str_date', 'startCharIndex': 64, 'endCharIndex': 73},
#    {'entityName': 'dst_city', 'startCharIndex': 86, 'endCharIndex': 92}]},
#  {'text': "good afternoon, i'd like to book a trip with my son from august 18 to august 29. he and i would be leaving from curitiba. what destinations can you offer?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 57,
#     'endCharIndex': 66},
#    {'entityName': 'end_date', 'startCharIndex': 70, 'endCharIndex': 79},
#    {'entityName': 'or_city', 'startCharIndex': 112, 'endCharIndex': 120}]},
#  {'text': 'hi, my family and i are booking a trip to sacramento, can you help us?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 42,
#     'endCharIndex': 52}]},
#  {'text': "hi i need a break from gotham city, the crime rate is just too high. i'd like to go to hogsmead with 3 kids and 9 adults.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 23,
#     'endCharIndex': 34},
#    {'entityName': 'dst_city', 'startCharIndex': 87, 'endCharIndex': 95}]},
#  {'text': 'hello, i have 15 vacation days available between june 1st and august 31st. i am leaving from theed. i would like to go somewhere with lots of sunshine.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 49,
#     'endCharIndex': 57},
#    {'entityName': 'end_date', 'startCharIndex': 62, 'endCharIndex': 73},
#    {'entityName': 'or_city', 'startCharIndex': 93, 'endCharIndex': 98}]},
#  {'text': "hello! i live in munich and i'd like to book any kind of trip between monday, august 15th and friday august 26th for 3 adults and 3 kids.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 17,
#     'endCharIndex': 23},
#    {'entityName': 'str_date', 'startCharIndex': 70, 'endCharIndex': 89},
#    {'entityName': 'end_date', 'startCharIndex': 94, 'endCharIndex': 112}]},
#  {'text': 'hi im from punta cana looking to go on a trip',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 21}]},
#  {'text': 'hey! you can help me by finding a trip to philadelphia from maceio.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 42,
#     'endCharIndex': 54},
#    {'entityName': 'or_city', 'startCharIndex': 60, 'endCharIndex': 66}]},
#  {'text': "good afternoon. i'd like to book a business trip to new york from mannheim. what can you offer?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 52,
#     'endCharIndex': 60},
#    {'entityName': 'or_city', 'startCharIndex': 66, 'endCharIndex': 74}]},
#  {'text': 'i would like a vacation for one in mannheim from august 17 to september 7. my city of departure is porto alegre. it should cost less than $3000.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 35,
#     'endCharIndex': 43},
#    {'entityName': 'str_date', 'startCharIndex': 49, 'endCharIndex': 58},
#    {'entityName': 'end_date', 'startCharIndex': 62, 'endCharIndex': 73},
#    {'entityName': 'or_city', 'startCharIndex': 99, 'endCharIndex': 111},
#    {'entityName': 'budget', 'startCharIndex': 138, 'endCharIndex': 143}]},
#  {'text': 'hi i am planning on booking a vacation soon, around august 27th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 52,
#     'endCharIndex': 63}]},
#  {'text': 'hi! i hear hogsmeade has some excellent bars. can you book me a trip there from diagon alley, leaving on august 13th? for 7 men and women',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 11,
#     'endCharIndex': 20},
#    {'entityName': 'or_city', 'startCharIndex': 80, 'endCharIndex': 92},
#    {'entityName': 'str_date', 'startCharIndex': 105, 'endCharIndex': 116}]},
#  {'text': 'hi!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'we are 3 adults and three kids looking for a vacation between august 18 and september 4',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 62,
#     'endCharIndex': 71},
#    {'entityName': 'end_date', 'startCharIndex': 76, 'endCharIndex': 87}]},
#  {'text': 'hi i’m looking to go on a trip to caprica',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 34,
#     'endCharIndex': 41}]},
#  {'text': "hi! i'd like to go to boston from mos eisley on august 15th.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 22,
#     'endCharIndex': 28},
#    {'entityName': 'or_city', 'startCharIndex': 34, 'endCharIndex': 44},
#    {'entityName': 'str_date', 'startCharIndex': 48, 'endCharIndex': 59}]},
#  {'text': 'hi im looking to make a quick trip im from tampa and want to go to dallas',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 43,
#     'endCharIndex': 48},
#    {'entityName': 'dst_city', 'startCharIndex': 67, 'endCharIndex': 73}]},
#  {'text': 'hi im from leon and looking to get away',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 15}]},
#  {'text': "i'd like to go to manaus from miami between august 19th and september 2nd.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 18,
#     'endCharIndex': 24},
#    {'entityName': 'or_city', 'startCharIndex': 30, 'endCharIndex': 35},
#    {'entityName': 'str_date', 'startCharIndex': 44, 'endCharIndex': 55},
#    {'entityName': 'end_date', 'startCharIndex': 60, 'endCharIndex': 73}]},
#  {'text': 'i am one person voyaging to tampa. i can depart from indianapolis. must be between 20th and 31 august.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 28,
#     'endCharIndex': 33},
#    {'entityName': 'or_city', 'startCharIndex': 53, 'endCharIndex': 65},
#    {'entityName': 'str_date', 'startCharIndex': 83, 'endCharIndex': 87},
#    {'entityName': 'end_date', 'startCharIndex': 92, 'endCharIndex': 101}]},
#  {'text': 'heyo!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': "hi! i'm looking for a trip to milan with two of my best friends for march break, what's available?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 30,
#     'endCharIndex': 35}]},
#  {'text': 'hello there! looking to get away between august 27th and august 30th! can you help me?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 41,
#     'endCharIndex': 52},
#    {'entityName': 'end_date', 'startCharIndex': 57, 'endCharIndex': 68}]},
#  {'text': 'hi going on vacation with my family can you help me book a vacation?',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'good morning.', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'i am from london and am looking to book a vacation package!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 10,
#     'endCharIndex': 16}]},
#  {'text': 'i want to book a trip to valencia!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 25,
#     'endCharIndex': 33}]},
#  {'text': 'hi. i am in dire need of a vacation.',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi. i need to book a vacation to long beach between august 25 and september 3. departure is from paris',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 33,
#     'endCharIndex': 43},
#    {'entityName': 'str_date', 'startCharIndex': 52, 'endCharIndex': 61},
#    {'entityName': 'end_date', 'startCharIndex': 66, 'endCharIndex': 77},
#    {'entityName': 'or_city', 'startCharIndex': 97, 'endCharIndex': 102}]},
#  {'text': "hi! i'd like to do some vacation shopping!",
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi i am planning my honeymoon for my wife and myself. i am looking for the best deal but it needs to be the best time! can you helo us?',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hey im looking for a nice get away can you help me?',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'the police are after me, and i need to leave kobe between august 27 and september 2.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 45,
#     'endCharIndex': 49},
#    {'entityName': 'str_date', 'startCharIndex': 58, 'endCharIndex': 67},
#    {'entityName': 'end_date', 'startCharIndex': 72, 'endCharIndex': 83}]},
#  {'text': "hi we're from miami and we want to go to paris, can you help out?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 14,
#     'endCharIndex': 19},
#    {'entityName': 'dst_city', 'startCharIndex': 41, 'endCharIndex': 46}]},
#  {'text': 'hi im looking to go to fukuoka',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 23,
#     'endCharIndex': 30}]},
#  {'text': 'hello wozbot!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'hi im going on spriinggg break! can you help me and my friends book a package?',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': "hi wozbot. i'd like to book a vacation for my 7 kids and myself.",
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi im looking to book my honeymoon',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': "hi wozbot! i'd like to book a spring break vacation for myself and 3 of my best friends",
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi im planning my spring break can you help me find the best deals?',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi 7 colleagues and i are planning on going on a trip can you help?',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': "hi wozbot! my husband and i are recently married and madly in love. we're looking for a fantastic honeymoon vacation. we live in mannheim and we'd like to go to kyoto for 6 days leaving on august 19. what can you do for me?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 129,
#     'endCharIndex': 137},
#    {'entityName': 'dst_city', 'startCharIndex': 161, 'endCharIndex': 166},
#    {'entityName': 'str_date', 'startCharIndex': 189, 'endCharIndex': 198}]},
#  {'text': 'hi im from coruscant looking to go to atlantis',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 20},
#    {'entityName': 'dst_city', 'startCharIndex': 38, 'endCharIndex': 46}]},
#  {'text': 'hi im from punta cana can you help me find a vacation',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 21}]},
#  {'text': 'i want to get away for a bit! im from houston',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 38,
#     'endCharIndex': 45}]},
#  {'text': 'i live in toronto, can we se what packages are available in cairo from august 17 to september 7?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 10,
#     'endCharIndex': 17},
#    {'entityName': 'dst_city', 'startCharIndex': 60, 'endCharIndex': 65},
#    {'entityName': 'str_date', 'startCharIndex': 71, 'endCharIndex': 80},
#    {'entityName': 'end_date', 'startCharIndex': 84, 'endCharIndex': 95}]},
#  {'text': 'hi i need a 5 day get away!',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi there! my family and i are looking to go to burlington',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 47,
#     'endCharIndex': 57}]},
#  {'text': 'hi im looking to book  trip. anything leaving from kakariko village?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 51,
#     'endCharIndex': 67}]},
#  {'text': "good afternoon, my man! i'd like to plan a honeymoon in naples for 5 days leaving from madrid on august 17. what is available?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 56,
#     'endCharIndex': 62},
#    {'entityName': 'or_city', 'startCharIndex': 87, 'endCharIndex': 93},
#    {'entityName': 'str_date', 'startCharIndex': 97, 'endCharIndex': 106}]},
#  {'text': 'hi i want to plan my honeymoon to rome',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 34,
#     'endCharIndex': 38}]},
#  {'text': 'hi im from houston and i want to go to san antonio, but i have strict dates can you help?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 18},
#    {'entityName': 'dst_city', 'startCharIndex': 39, 'endCharIndex': 50}]},
#  {'text': 'hi im from los angeles. looking for a good vacation',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 22}]},
#  {'text': 'i have 11 days of time off starting on august 17. can you offer me any vacation packages leaving from portland?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 39,
#     'endCharIndex': 48},
#    {'entityName': 'or_city', 'startCharIndex': 102, 'endCharIndex': 110}]},
#  {'text': 'hi im travelling from nagoya. i would like to go on vacation on august 26th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 22,
#     'endCharIndex': 28},
#    {'entityName': 'str_date', 'startCharIndex': 64, 'endCharIndex': 75}]},
#  {'text': 'hi! i have a $3300 budget and am looking for a vacation',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 13,
#     'endCharIndex': 18}]},
#  {'text': 'hi im looking to go on a trip to baltimore',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 33,
#     'endCharIndex': 42}]},
#  {'text': "my name is gary peter and i'd like to book a trip to diagon alley from godric's hollow on august 13th.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 53,
#     'endCharIndex': 65},
#    {'entityName': 'or_city', 'startCharIndex': 71, 'endCharIndex': 86},
#    {'entityName': 'str_date', 'startCharIndex': 90, 'endCharIndex': 101}]},
#  {'text': 'hi! my 3 best friends and i are looking for a trip to neverland between august 16 and 19 on a very tight budget of $3500. what can you do for us?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 54,
#     'endCharIndex': 63},
#    {'entityName': 'str_date', 'startCharIndex': 72, 'endCharIndex': 81},
#    {'entityName': 'end_date', 'startCharIndex': 86, 'endCharIndex': 88},
#    {'entityName': 'budget', 'startCharIndex': 115, 'endCharIndex': 120}]},
#  {'text': 'hi im from barkcelona, looking for a trip!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 21}]},
#  {'text': 'hi i want to go on vacation i leave from cancun',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 41,
#     'endCharIndex': 47}]},
#  {'text': 'hi im taking the family on a trip to manaus is that possible with a budget of $3900',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 37,
#     'endCharIndex': 43},
#    {'entityName': 'budget', 'startCharIndex': 78, 'endCharIndex': 83}]},
#  {'text': 'hi looking for a vacation to hamburg',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 29,
#     'endCharIndex': 36}]},
#  {'text': "hello, i'd like to book a trip to mos eisley from hogsmeade on august 13.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 34,
#     'endCharIndex': 44},
#    {'entityName': 'or_city', 'startCharIndex': 50, 'endCharIndex': 59},
#    {'entityName': 'str_date', 'startCharIndex': 63, 'endCharIndex': 72}]},
#  {'text': "hi! i'd like to plan my honeymoon, but i've spent way too much on my wedding and need to stick to a budget of $4600. can you offer anything to marseille for 5 days leaving from salvador on august 17?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 110,
#     'endCharIndex': 115},
#    {'entityName': 'dst_city', 'startCharIndex': 143, 'endCharIndex': 152},
#    {'entityName': 'or_city', 'startCharIndex': 177, 'endCharIndex': 185},
#    {'entityName': 'str_date', 'startCharIndex': 189, 'endCharIndex': 198}]},
#  {'text': 'hi im fro termina and i want to go on vacation on august 13th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 10,
#     'endCharIndex': 17},
#    {'entityName': 'str_date', 'startCharIndex': 50, 'endCharIndex': 61}]},
#  {'text': 'hi i am looking to go to punta cana with my three friends',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 25,
#     'endCharIndex': 35}]},
#  {'text': "hello, i'd like to go to birmingham for 7 days on my honeymoon, leaving from denver on august 18. what can you offer?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 25,
#     'endCharIndex': 35},
#    {'entityName': 'or_city', 'startCharIndex': 77, 'endCharIndex': 83},
#    {'entityName': 'str_date', 'startCharIndex': 87, 'endCharIndex': 96}]},
#  {'text': 'hi im from neverland! and i want to go to mos eisley',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 11,
#     'endCharIndex': 20},
#    {'entityName': 'dst_city', 'startCharIndex': 42, 'endCharIndex': 52}]},
#  {'text': 'hello! were leaving from brasilia and looking to book our honeymoon',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 25,
#     'endCharIndex': 33}]},
#  {'text': 'hi im in the middle of travelling  and i want to go to porto!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 55,
#     'endCharIndex': 60}]},
#  {'text': 'hi there! i finally have some vacation time starting on august 22nd and i am hoping to go away somewhere really far away and getting away from it all. do you have any suggestions for me?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 56,
#     'endCharIndex': 67}]},
#  {'text': "i'd like to book a trip to monterrey from august 17th to august 25th.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 27,
#     'endCharIndex': 36},
#    {'entityName': 'str_date', 'startCharIndex': 42, 'endCharIndex': 53},
#    {'entityName': 'end_date', 'startCharIndex': 57, 'endCharIndex': 68}]},
#  {'text': 'hey i wanna go to hiroshima w my fam',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 18,
#     'endCharIndex': 27}]},
#  {'text': "hi! i'm looking to book a trip somewhere between august 19th and september 3rd. my budget is 1700.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 49,
#     'endCharIndex': 60},
#    {'entityName': 'end_date', 'startCharIndex': 65, 'endCharIndex': 78},
#    {'entityName': 'budget', 'startCharIndex': 93, 'endCharIndex': 97}]},
#  {'text': "hey, i'm looking to go to theed from caprica on august 13th",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 26,
#     'endCharIndex': 31},
#    {'entityName': 'or_city', 'startCharIndex': 37, 'endCharIndex': 44},
#    {'entityName': 'str_date', 'startCharIndex': 48, 'endCharIndex': 59}]},
#  {'text': "i'd like to book a trip from london to somewhere, for august 17th to august 31st.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 29,
#     'endCharIndex': 35},
#    {'entityName': 'str_date', 'startCharIndex': 54, 'endCharIndex': 65},
#    {'entityName': 'end_date', 'startCharIndex': 69, 'endCharIndex': 80}]},
#  {'text': 'ay whats up?', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'good morning.  we are planning a family reunion and since we are spread out all over the world, we have decided on a couple of possibilities. can you please give me information on packages available in fukuoka? my husband and i would be leaving from manaus and we will be travelling with our 4 children.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 202,
#     'endCharIndex': 209},
#    {'entityName': 'or_city', 'startCharIndex': 250, 'endCharIndex': 256}]},
#  {'text': 'hi im in mannheim and want to spend a week away',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 9,
#     'endCharIndex': 17}]},
#  {'text': "hi. i'd like to find a trip to san diego. i can leave from belo horizonte. i'd like to travel between august 27th and august 31st if possible. my dates are flexible.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 31,
#     'endCharIndex': 40},
#    {'entityName': 'or_city', 'startCharIndex': 59, 'endCharIndex': 73},
#    {'entityName': 'str_date', 'startCharIndex': 102, 'endCharIndex': 113},
#    {'entityName': 'end_date', 'startCharIndex': 118, 'endCharIndex': 129}]},
#  {'text': "hi! i'm getting married and we are super tight on money but i want to be able to give my new bride the best possible honeymoon despite our tight budget, do you have any cool honeymoon destinations that you can recommend?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 41,
#     'endCharIndex': 46}]},
#  {'text': 'id like to book a trip. i have a very tight budget of $2600. i would need to be there between august 27th to september 11th.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 54,
#     'endCharIndex': 59},
#    {'entityName': 'str_date', 'startCharIndex': 94, 'endCharIndex': 105},
#    {'entityName': 'end_date', 'startCharIndex': 109, 'endCharIndex': 123}]},
#  {'text': 'hey i have 14 kids. we wanna go to theed',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 35,
#     'endCharIndex': 40}]},
#  {'text': 'hello. i want to go to buenos aires\ni live in puebla',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 23,
#     'endCharIndex': 35},
#    {'entityName': 'or_city', 'startCharIndex': 46, 'endCharIndex': 52}]},
#  {'text': "i'd like to book a trip from chicago to san diego between august 26th and september 5th.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 29,
#     'endCharIndex': 36},
#    {'entityName': 'dst_city', 'startCharIndex': 40, 'endCharIndex': 49},
#    {'entityName': 'str_date', 'startCharIndex': 58, 'endCharIndex': 69},
#    {'entityName': 'end_date', 'startCharIndex': 74, 'endCharIndex': 87}]},
#  {'text': 'hi there', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': "hi, i'm a very interesting person from stuttgart and i need to get myself to sapporo. i am traveling with a friend.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 39,
#     'endCharIndex': 48},
#    {'entityName': 'dst_city', 'startCharIndex': 77, 'endCharIndex': 84}]},
#  {'text': 'hello, i want to book a trip to coruscant.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 32,
#     'endCharIndex': 41}]},
#  {'text': "hey, i'm looking to find a vacation from valencia to osaka.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 41,
#     'endCharIndex': 49},
#    {'entityName': 'dst_city', 'startCharIndex': 53, 'endCharIndex': 58}]},
#  {'text': "hello! i am located in germany and i'm getting married next month, we would really like to go to naples . can you find me a nice package please!",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 23,
#     'endCharIndex': 30},
#    {'entityName': 'dst_city', 'startCharIndex': 97, 'endCharIndex': 103}]},
#  {'text': 'hi i wanna look into packages to san antonio',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 33,
#     'endCharIndex': 44}]},
#  {'text': "i'm looking to book trip for spring break for 4 people. i have a tight budget of 4600",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 81,
#     'endCharIndex': 85}]},
#  {'text': 'hi i am burnt out... i need a vacation',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hey there! my girlfriends and i are looking to go on a girlie trip for spring break. but we want to go somewhere wild like san juan! ',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 123,
#     'endCharIndex': 131}]},
#  {'text': "hi! i'm looking to book a trip from termina to atlantis with my family. this includes 1 adult and 3 kids. my budget is at most $3300.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 36,
#     'endCharIndex': 43},
#    {'entityName': 'dst_city', 'startCharIndex': 47, 'endCharIndex': 55},
#    {'entityName': 'budget', 'startCharIndex': 127, 'endCharIndex': 132}]},
#  {'text': "hi, i'm trying to book a trip from madrid.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 35,
#     'endCharIndex': 41}]},
#  {'text': "hey there, i'm doing some travelling for business soon. it needs to be around august 18-august 26. what can you do for me?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 78,
#     'endCharIndex': 87},
#    {'entityName': 'end_date', 'startCharIndex': 88, 'endCharIndex': 97}]},
#  {'text': "me again... i'm still burnt out from work",
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': "hi! i'd really like to try and book a trip for me and 3 of my friends for spring break.  i have a budget of $2100.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 108,
#     'endCharIndex': 113}]},
#  {'text': "hey, i'm looking to book my honeymoon from houston to santo domingo for a week on august 26th. my budget is 1500.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 43,
#     'endCharIndex': 50},
#    {'entityName': 'dst_city', 'startCharIndex': 54, 'endCharIndex': 67},
#    {'entityName': 'str_date', 'startCharIndex': 82, 'endCharIndex': 93},
#    {'entityName': 'budget', 'startCharIndex': 108, 'endCharIndex': 112}]},
#  {'text': "hey man, i'm like the best pokémon hunter in the world and i'm only missing one and i need to get to punta cana cause rumour like has it he's at one of those places but you know rumours are only rumours so i'm not in a total hurry but i want to see how much it will cost me to get go there, can you give me some pricing",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 101,
#     'endCharIndex': 111}]},
#  {'text': 'helllloooo, couple of lovebirds here looking to get away to burlington for our honeymoon :heart_eyes::smiley_cat::two_women_holding_hands:',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 60,
#     'endCharIndex': 70}]},
#  {'text': "i'm looking to book a trip from hamburg starting august 15th. i have a 14 day vacation. what packages can you recommend?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 32,
#     'endCharIndex': 39},
#    {'entityName': 'str_date', 'startCharIndex': 49, 'endCharIndex': 60}]},
#  {'text': 'hi my wife and i wanna bring our 7 little lads n lassies to kochi leaving from san diego  we can spend 28500 ',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 60,
#     'endCharIndex': 65},
#    {'entityName': 'or_city', 'startCharIndex': 79, 'endCharIndex': 88},
#    {'entityName': 'budget', 'startCharIndex': 103, 'endCharIndex': 108}]},
#  {'text': 'hi i need to get to mexico please find me a flight from punta cana',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 20,
#     'endCharIndex': 26},
#    {'entityName': 'or_city', 'startCharIndex': 56, 'endCharIndex': 66}]},
#  {'text': "i'm looking to book a trip to fukuoka from mannheim leaving on august 27th for my honeymoon.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 30,
#     'endCharIndex': 37},
#    {'entityName': 'or_city', 'startCharIndex': 43, 'endCharIndex': 51},
#    {'entityName': 'str_date', 'startCharIndex': 63, 'endCharIndex': 74}]},
#  {'text': 'good afternoon my name is carolina and i want to book a trip. can you please tell me what specials you have at the moment leaving on august 25  and going to guadalajara, i want to go visit my family.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 133,
#     'endCharIndex': 142},
#    {'entityName': 'dst_city', 'startCharIndex': 157, 'endCharIndex': 168}]},
#  {'text': "hey what's available from mtl to mexico city?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 26,
#     'endCharIndex': 29},
#    {'entityName': 'dst_city', 'startCharIndex': 33, 'endCharIndex': 44}]},
#  {'text': "hi. i'd like to book a trip from nagoya to phoenix from august 15th to august 29th.",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 33,
#     'endCharIndex': 39},
#    {'entityName': 'dst_city', 'startCharIndex': 43, 'endCharIndex': 50},
#    {'entityName': 'str_date', 'startCharIndex': 56, 'endCharIndex': 67},
#    {'entityName': 'end_date', 'startCharIndex': 71, 'endCharIndex': 82}]},
#  {'text': 'hey im trying to go on spriiiiing breeeaaaakkkk. san francisco is poppin right? lets go there',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 49,
#     'endCharIndex': 62}]},
#  {'text': 'good morning! i will be travelling with a colleague for business and we are thinking of tacking on a short vacation after. do you have any flights going from punta cana to cairo sometime between 26 august and 9 september?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 158,
#     'endCharIndex': 168},
#    {'entityName': 'dst_city', 'startCharIndex': 172, 'endCharIndex': 177},
#    {'entityName': 'str_date', 'startCharIndex': 195, 'endCharIndex': 204},
#    {'entityName': 'end_date', 'startCharIndex': 209, 'endCharIndex': 220}]},
#  {'text': "i'm looking to book a trip to chicago from brasilia. i booked work off from august 27th to september 10th and im looking for a 7 day trip",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 30,
#     'endCharIndex': 37},
#    {'entityName': 'or_city', 'startCharIndex': 43, 'endCharIndex': 51},
#    {'entityName': 'str_date', 'startCharIndex': 76, 'endCharIndex': 87},
#    {'entityName': 'end_date', 'startCharIndex': 91, 'endCharIndex': 105}]},
#  {'text': 'i want ot travel to melbourne. i will leave from kyoto',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 20,
#     'endCharIndex': 29},
#    {'entityName': 'or_city', 'startCharIndex': 49, 'endCharIndex': 54}]},
#  {'text': 'hi i wanna take a 12 day trip from hiroshima to phoenix, leaving on august 27th.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 35,
#     'endCharIndex': 44},
#    {'entityName': 'dst_city', 'startCharIndex': 48, 'endCharIndex': 55},
#    {'entityName': 'str_date', 'startCharIndex': 68, 'endCharIndex': 79}]},
#  {'text': 'hi, i live in diagon alley and we need to go to las vegas in august for a graffiti convention its gonna be so chill cant wait',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 14,
#     'endCharIndex': 26},
#    {'entityName': 'dst_city', 'startCharIndex': 48, 'endCharIndex': 57},
#    {'entityName': 'str_date', 'startCharIndex': 61, 'endCharIndex': 67}]},
#  {'text': 'need a vacay\ni only got 3 days off work tho august 27-31\ni wanna go to kobe whats available?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 44,
#     'endCharIndex': 53},
#    {'entityName': 'end_date', 'startCharIndex': 54, 'endCharIndex': 56},
#    {'entityName': 'dst_city', 'startCharIndex': 71, 'endCharIndex': 75}]},
#  {'text': 'looking to go from mos eisley to kyoto on august 27',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 19,
#     'endCharIndex': 29},
#    {'entityName': 'dst_city', 'startCharIndex': 33, 'endCharIndex': 38},
#    {'entityName': 'str_date', 'startCharIndex': 42, 'endCharIndex': 51}]},
#  {'text': 'i need to book a flight to find my last pokemon. i would need to leave from montreal and go to hiroshima. i will also need to leave on august 19th. im with 4 other adults as well.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 76,
#     'endCharIndex': 84},
#    {'entityName': 'dst_city', 'startCharIndex': 95, 'endCharIndex': 104},
#    {'entityName': 'str_date', 'startCharIndex': 135, 'endCharIndex': 146}]},
#  {'text': 'i want to take a trip from diagon alley to naples.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 27,
#     'endCharIndex': 39},
#    {'entityName': 'dst_city', 'startCharIndex': 43, 'endCharIndex': 49}]},
#  {'text': 'i want to go to tijuana.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 16,
#     'endCharIndex': 23}]},
#  {'text': 'hi i live in seattle and i really have to get out of this seedy town for a while',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 13,
#     'endCharIndex': 20}]},
#  {'text': 'hello hello i am travelling with my 9 sisters and my child to our family reunion in corsucant next month! we will spend 1800 max, what can you do?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 84,
#     'endCharIndex': 93},
#    {'entityName': 'str_date', 'startCharIndex': 94, 'endCharIndex': 104},
#    {'entityName': 'budget', 'startCharIndex': 120, 'endCharIndex': 124}]},
#  {'text': 'hey im looking to check out fortaleza. im leaving from sapporo on august 27',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 28,
#     'endCharIndex': 37},
#    {'entityName': 'or_city', 'startCharIndex': 55, 'endCharIndex': 62},
#    {'entityName': 'str_date', 'startCharIndex': 66, 'endCharIndex': 75}]},
#  {'text': 'hi i would like to book a vacation from august 27th to august 30th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 40,
#     'endCharIndex': 51},
#    {'entityName': 'end_date', 'startCharIndex': 55, 'endCharIndex': 66}]},
#  {'text': 'i am looking for a honeymoon package to manaus. i heard it is the perfect honeymooners paradise. the wedding cost us an arm and a leg so i really need something reasonable.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 40,
#     'endCharIndex': 46}]},
#  {'text': 'im married now boi. takin my new spouse 2 mexico city\n10 days\nlets keep it 1500 max\ncool?\nleaving from detroit\ndo your thang',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 42,
#     'endCharIndex': 53},
#    {'entityName': 'budget', 'startCharIndex': 75, 'endCharIndex': 79},
#    {'entityName': 'or_city', 'startCharIndex': 103, 'endCharIndex': 110}]},
#  {'text': "i'm looking to go on a trip but i'm not sure where. can i get information for a trip from toluca to paris from august 25th to september 9th?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 90,
#     'endCharIndex': 96},
#    {'entityName': 'dst_city', 'startCharIndex': 100, 'endCharIndex': 105},
#    {'entityName': 'str_date', 'startCharIndex': 111, 'endCharIndex': 122},
#    {'entityName': 'end_date', 'startCharIndex': 126, 'endCharIndex': 139}]},
#  {'text': 'hello!!!!! we are planning a family trip with my brother and his kids and we are thinking gotham city would be super cool for the kids. do you have any packages for less than $3200?',
#   'intentName': 'BookFlight',
# ...
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 22,
#     'endCharIndex': 28},
#    {'entityName': 'dst_city', 'startCharIndex': 77, 'endCharIndex': 83}]},
#  {'text': 'my team and i need to get to san diego. need to leave by sept 6. it is a matter of life and death!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 29,
#     'endCharIndex': 38},
#    {'entityName': 'str_date', 'startCharIndex': 57, 'endCharIndex': 63}]},
#  {'text': 'hi there. i have 2000 to spend on my lovely parents\ni want to get them out of puebla sometime this month\nseptember 3 to 16\nwhats the longest trip you can book me?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'budget',
#     'startCharIndex': 17,
#     'endCharIndex': 21},
#    {'entityName': 'or_city', 'startCharIndex': 78, 'endCharIndex': 84},
#    {'entityName': 'str_date', 'startCharIndex': 105, 'endCharIndex': 116},
#    {'entityName': 'end_date', 'startCharIndex': 120, 'endCharIndex': 122}]},
#  {'text': 'hello bot! could you do me a favour and check if you do flights from barcelona to manas?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 69,
#     'endCharIndex': 78},
#    {'entityName': 'dst_city', 'startCharIndex': 82, 'endCharIndex': 87}]},
#  {'text': "i'd like to make a pilgrimage from jerusalem to indianapolis. there are 8 of us in total",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 35,
#     'endCharIndex': 44},
#    {'entityName': 'dst_city', 'startCharIndex': 48, 'endCharIndex': 60}]},
#  {'text': 'can you get me to kyoto',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 18,
#     'endCharIndex': 23}]},
#  {'text': 'you fly out of beijing?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 15,
#     'endCharIndex': 22}]},
#  {'text': 'i need to book a vacation. ok i’m leaving from rio de janeiro\ni don’t particularly care about where we go',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 47,
#     'endCharIndex': 61}]},
#  {'text': 'hello', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'we have 6 adults looking to book a trip',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'kyoto to boston',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 5},
#    {'entityName': 'dst_city', 'startCharIndex': 9, 'endCharIndex': 15}]},
#  {'text': 'we have a big group to book for!',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hey, i need a break from work, a break from sl',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 44,
#     'endCharIndex': 46}]},
#  {'text': 'get me to kyoto!!!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 10,
#     'endCharIndex': 15}]},
#  {'text': 'hi there!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'one first class ticket to santios',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 26,
#     'endCharIndex': 33}]},
#  {'text': 'do you do flights out of san antonio?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 25,
#     'endCharIndex': 36}]},
#  {'text': 'looking to go to guadalajara',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 17,
#     'endCharIndex': 28}]},
#  {'text': 'can u book a couple adults out of alexandria? send em anywhere i dont care. sept 16 until the 29th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 34,
#     'endCharIndex': 44},
#    {'entityName': 'str_date', 'startCharIndex': 76, 'endCharIndex': 83},
#    {'entityName': 'end_date', 'startCharIndex': 94, 'endCharIndex': 98}]},
#  {'text': 'hello. looking to travel out of leon with a client\ni want to find a really nice hotel to impress him - have big business deals to close',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 32,
#     'endCharIndex': 36}]},
#  {'text': "i'm inquiring to see if you have trips from san jose to calgary",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 44,
#     'endCharIndex': 52},
#    {'entityName': 'dst_city', 'startCharIndex': 56, 'endCharIndex': 63}]},
#  {'text': 'hello there', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'hi there. looking to get out of toronto with a few friends',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 32,
#     'endCharIndex': 39}]},
#  {'text': 'i got married in puebla this past tuesday',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 17,
#     'endCharIndex': 23}]},
#  {'text': 'do you do flights out of punta cana?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 25,
#     'endCharIndex': 35}]},
#  {'text': 'hey-oh! i need to leave indianapolis tomorrow after my wedding\ntwo adults travelling, of course, and we want to go to kingston for 9 days. what can you give me?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 24,
#     'endCharIndex': 36},
#    {'entityName': 'dst_city', 'startCharIndex': 118, 'endCharIndex': 126}]},
#  {'text': 'can you get me out of pittsburgh on sunday the 11th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 22,
#     'endCharIndex': 32},
#    {'entityName': 'str_date', 'startCharIndex': 36, 'endCharIndex': 51}]},
#  {'text': 'santiago to burlington, go!',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 8},
#    {'entityName': 'dst_city', 'startCharIndex': 12, 'endCharIndex': 22}]},
#  {'text': 'hello, there!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'get me out of berlin',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 14,
#     'endCharIndex': 20}]},
#  {'text': 'hi there', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'just looking into vacations departing phili. where could i go for under 1200?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 38,
#     'endCharIndex': 43},
#    {'entityName': 'budget', 'startCharIndex': 72, 'endCharIndex': 76}]},
#  {'text': 'i am just dying to get to madrid and check out this hot new food truck that serves llama meat tacos. i’m on a limited budget though.. so if you could get me there sometime in the next month or so for like 1100 bucks it would be amazing. let’s try leaving from las vegas maybe?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 26,
#     'endCharIndex': 32},
#    {'entityName': 'budget', 'startCharIndex': 205, 'endCharIndex': 209},
#    {'entityName': 'or_city', 'startCharIndex': 260, 'endCharIndex': 269}]},
#  {'text': 'i need to impress some clients with an extravagant trip',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'essen to osaka. sept 2-16',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 5},
#    {'entityName': 'dst_city', 'startCharIndex': 9, 'endCharIndex': 14},
#    {'entityName': 'str_date', 'startCharIndex': 16, 'endCharIndex': 22},
#    {'entityName': 'end_date', 'startCharIndex': 23, 'endCharIndex': 25}]},
#  {'text': 'i’d like to see where i can go from hiroshima. between now and september 5',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 36,
#     'endCharIndex': 45},
#    {'entityName': 'str_date', 'startCharIndex': 55, 'endCharIndex': 58},
#    {'entityName': 'end_date', 'startCharIndex': 63, 'endCharIndex': 74}]},
#  {'text': 'i have a movie shoot to go to in salvador. get me there from belem',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 33,
#     'endCharIndex': 41},
#    {'entityName': 'or_city', 'startCharIndex': 61, 'endCharIndex': 66}]},
#  {'text': 'hello', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'ok! so i am planning a trip with my 6 best friends. we want to go from guadalajara to somewhere else\nfirst on our list is cairo. could you get us there?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 71,
#     'endCharIndex': 82},
#    {'entityName': 'dst_city', 'startCharIndex': 122, 'endCharIndex': 127}]},
#  {'text': 'hello, get me to frankfurt. leaving punta cana.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 17,
#     'endCharIndex': 26},
#    {'entityName': 'or_city', 'startCharIndex': 36, 'endCharIndex': 46}]},
#  {'text': 'hello - need to fly out to queenstown soon',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 27,
#     'endCharIndex': 37}]},
#  {'text': 'hello. i’m hearing good things about the uni in hiroshima. i would like to visit there and leave from burlington.',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 48,
#     'endCharIndex': 57},
#    {'entityName': 'or_city', 'startCharIndex': 102, 'endCharIndex': 112}]},
#  {'text': 'my next destination is mexico city! but can i get there from tijuana is the million dollar question',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 23,
#     'endCharIndex': 34},
#    {'entityName': 'or_city', 'startCharIndex': 61, 'endCharIndex': 68}]},
#  {'text': 'kingston to salvador u got this?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 8},
#    {'entityName': 'dst_city', 'startCharIndex': 12, 'endCharIndex': 20}]},
#  {'text': 'i want to book a flight for myself and 6 grandchildren',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': "hello! i'd like to book something for myself. i have quite a few vacation days coming up",
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': "pittsburgh to guadalajara. what's the cost?",
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 10},
#    {'entityName': 'dst_city', 'startCharIndex': 14, 'endCharIndex': 25}]},
#  {'text': 'ulsan to vitoria, 1 business class ticket',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 5},
#    {'entityName': 'dst_city', 'startCharIndex': 9, 'endCharIndex': 16}]},
#  {'text': 'i need to get to baltimore on important business',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 17,
#     'endCharIndex': 26}]},
#  {'text': 'hi there!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'you too!', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'heyyyy there', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'find me something flashy for 6 adults in buenos aires. its my birthday so i don’t care what it costs',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 41,
#     'endCharIndex': 53}]},
#  {'text': 'drop what you’re doing and book me a flgith!',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'whats your best hotel in paris?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 25,
#     'endCharIndex': 30}]},
#  {'text': 'i want vacation plz',
#   'intentName': 'BookFlight',
#   'entityLabels': []},
#  {'text': 'hi there. first off, do you do any flights departing jerusalem?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 53,
#     'endCharIndex': 62}]},
#  {'text': 'looking to take my squad out to punta cana! i’ll pay whatever it takes to fly out of tel aviv',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 32,
#     'endCharIndex': 42},
#    {'entityName': 'or_city', 'startCharIndex': 85, 'endCharIndex': 93}]},
#  {'text': 'i have 8 days off coming up. really want to get out of the country\nthe country being brazil\ndo you have flights to mexico city?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 85,
#     'endCharIndex': 91},
#    {'entityName': 'dst_city', 'startCharIndex': 115, 'endCharIndex': 126}]},
#  {'text': 'hello', 'intentName': 'BookFlight', 'entityLabels': []},
#  {'text': 'looking to go from san francisco to marseille. book me for september 18 to 22. let me know if its more than 2800 because thats all i can afford',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 19,
#     'endCharIndex': 32},
#    {'entityName': 'dst_city', 'startCharIndex': 36, 'endCharIndex': 45},
#    {'entityName': 'str_date', 'startCharIndex': 59, 'endCharIndex': 71},
#    {'entityName': 'end_date', 'startCharIndex': 75, 'endCharIndex': 77},
#    {'entityName': 'budget', 'startCharIndex': 108, 'endCharIndex': 112}]},
#  {'text': 'i need to book a business trip - something impressive... thinking… las vegas\n3 adults find me the best you can out of mannheim after september 11th',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 67,
#     'endCharIndex': 76},
#    {'entityName': 'or_city', 'startCharIndex': 118, 'endCharIndex': 126},
#    {'entityName': 'str_date', 'startCharIndex': 133, 'endCharIndex': 147}]},
#  {'text': 'las vegas to mexico city for 7 please',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 0,
#     'endCharIndex': 9},
#    {'entityName': 'dst_city', 'startCharIndex': 13, 'endCharIndex': 24}]},
#  {'text': 'hello. i need paris to barcelonna sept 18 to 22',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 14,
#     'endCharIndex': 19},
#    {'entityName': 'dst_city', 'startCharIndex': 23, 'endCharIndex': 33},
#    {'entityName': 'str_date', 'startCharIndex': 34, 'endCharIndex': 41},
#    {'entityName': 'end_date', 'startCharIndex': 45, 'endCharIndex': 47}]},
#  {'text': '6 adults to rosario from toluca it needs to be impressive',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 12,
#     'endCharIndex': 19},
#    {'entityName': 'or_city', 'startCharIndex': 25, 'endCharIndex': 31}]},
#  {'text': 'get me to manaus from toronto',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'dst_city',
#     'startCharIndex': 10,
#     'endCharIndex': 16},
#    {'entityName': 'or_city', 'startCharIndex': 22, 'endCharIndex': 29}]},
#  {'text': 'i have a vacation starting next week, i can hardly contain my excitement getting out of st. petersburg for 12 days will be dope. what kind of destinations do you offer?',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 88,
#     'endCharIndex': 102}]},
#  {'text': 'from between sept 6 and sept 11, i’m on break. leaving from columbus',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'str_date',
#     'startCharIndex': 13,
#     'endCharIndex': 19},
#    {'entityName': 'end_date', 'startCharIndex': 24, 'endCharIndex': 31},
#    {'entityName': 'or_city', 'startCharIndex': 60, 'endCharIndex': 68}]},
#  {'text': 'im broke but wanna dip out of north vancouver',
#   'intentName': 'BookFlight',
#   'entityLabels': [{'entityName': 'or_city',
#     'startCharIndex': 30,
#     'endCharIndex': 45}]},
#  ...]

# %%
train, test = train_test_split(luis_data, test_size=0.3, random_state=42)

# %%
print("Length train: " + str(len(train)))
print("Length test: " + str(len(test)))
# Out:
# Length train: 958
# Length test: 411

# %%
with open("luis_data.json", "w") as outfile:
    json.dump(luis_data, outfile)

with open("train.json", "w") as outfile:
    json.dump(train, outfile)

with open("test.json", "w") as outfile:
    json.dump(test, outfile)
